# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.predict import predict_crop

print(predict_crop(90, 42, 43, 20.5, 80, 6.5, 200))
# Out:
# 🌱 Recommended Crop: RICE
#
# 📊 Why this crop is suitable:
# - High nitrogen levels support strong vegetative growth.
# - Adequate rainfall ensures sufficient water supply.
# - Moderate temperature is ideal for crop development.
# - Soil pH is optimal for nutrient absorption.
#
# 🧠 Conclusion:
# Based on the soil and environmental conditions, rice is the most suitable crop for cultivation.
